# %% [markdown]
# # Task 1: A list of dictionaries

# %%
transactions = [
    {"id": 1, "product": "Laptop", "price": 1200, "quantity": 2, "region": "EU"},
    {"id": 2, "product": "Phone", "price": 800, "quantity": -1, "region": "US"},
    {"id": 3, "product": "Tablet", "price": 0, "quantity": 5, "region": "EU"},
    {"id": 4, "product": "Monitor", "price": 350, "quantity": 3, "region": "US"},
    {"id": 5, "product": "Laptop", "price": 1200, "quantity": 1, "region": "EU"},
    {"id": 6, "product": "Keyboard", "price": 75, "quantity": 10, "region": "APAC"},
]

#a)

# Create new dictionary and add items that match critera to it
filtered = []
for dictionary in transactions: 
    if dictionary["price"] > 0 and dictionary["quantity"] >= 0:
        filtered.append(dictionary)

#b)

for transaction in filtered:
    transaction["total"] = transaction["price"] * transaction["quantity"]

#c)

# Creating three lists and adding their respective transactions to them
EU = []
US = []
APAC = []
for transaction in filtered:
    if transaction["region"] == "EU":
        EU.append(transaction)
    elif transaction["region"] == "US":
        US.append(transaction)
    else:
        APAC.append(transaction)

totals = {}

regiontotal = 0
for transaction in EU: 
    regiontotal += transaction["total"]
totals["EU"] = regiontotal

regiontotal = 0
for transaction in US: 
    regiontotal += transaction["total"]
totals["US"] = regiontotal

regiontotal = 0
for transaction in APAC: 
    regiontotal += transaction["total"]
totals["APAC"] = regiontotal


#d)

largest = 0
final_region=""

for region in totals:
    if totals[region] > largest:
        largest = totals[region]
        final_region = region

print(f"the largest region by revenue is {final_region}, and its total revenue is {largest}.")
# Out:
# the largest region by revenue is EU, and its total revenue is 3600.

# %% [markdown]
# ---
# # Task 2: creating a function

# %%
sales = [1200, 980, 1540, 870, 2010, 1650, 1300, 1100, 950, 1780, 2200, 1430, 1600, 1900]

def summarise_sales(summarise):
    dict = {}
    dict["total"] = sum(summarise)
    dict["average"] = round(dict["total"]/len(summarise), 2)
    dict["best_day"] = summarise.index(max(summarise))+1
    dict["worst_day"] = summarise.index(min(summarise))+1

    count = 0
    for day in summarise:
        if day > dict["average"]:
            count += 1
    dict["above_average_count"] = count
    
    return dict
    
print(summarise_sales(sales))
# Out:
# {'total': 20510, 'average': 1465.0, 'best_day': 11, 'worst_day': 4, 'above_average_count': 7}

# %% [markdown]
# ---
# # Task 3: Loops

# %%
students = [
    {"name": "Anna", "grade": 85, "attendance": 0.92},
    {"name": "Erik", "grade": 58, "attendance": 0.75},
    {"name": "Mia", "grade": 91, "attendance": 0.98},
    {"name": "Leo", "grade": 44, "attendance": 0.60},
    {"name": "Sara", "grade": 72, "attendance": 0.88},
    {"name": "Tom", "grade": 67, "attendance": 0.70},
    {"name": "Nina", "grade": 95, "attendance": 0.99},
    {"name": "Olli", "grade": 50, "attendance": 0.65},
]

# a)
print("a)")
passing = []

for student in students:
    if student["grade"] >= 50:
        passing.append(student["name"])

print(f"Passing students: {passing}")

#b)
print("b)")
for student in students:
    message = "Excellent"
    if student["grade"] < 80:
         message = "Pass"
    if student["grade"] < 50:
        message = "Fail"
    name = student["name"]
    print(f"{name}: {message}.")

#c)
print("c)")
count = 0
for student in students:
    if student["attendance"] < 0.8:
        count+=1
print(f"Number of students with attendace over 0.80: {count}.")

#d)
print("d)")
name = ""
best_score = 0
for student in students:
    if student["grade"] > best_score:
        best_score = student["grade"]
        name = student["name"]
print(f"The best student is {name}, with a score of {best_score}.")

#e)
print("e)")
#https://stackoverflow.com/questions/5320871/how-to-find-the-min-max-value-of-a-common-key-in-a-list-of-dicts

best_grade = students.index(max(students, key=lambda student: student['grade'])) #The key argument uses a lambda function to find which dictionary entry to use to compare using max() function. My first time stumbling upon lambda functions, very nifty
print(f"The best student is {students[best_grade]['name']}, with a score of {students[best_grade]['grade']}.")
# Out:
# a)
# Passing students: ['Anna', 'Erik', 'Mia', 'Sara', 'Tom', 'Nina', 'Olli']
# b)
# Anna: Excellent.
# Erik: Pass.
# Mia: Excellent.
# Leo: Fail.
# Sara: Pass.
# Tom: Pass.
# Nina: Excellent.
# Olli: Pass.
# c)
# Number of students with attendace over 0.80: 4.
# d)
# The best student is Nina, with a score of 95.
# e)
# The best student is Nina, with a score of 95.

# %% [markdown]
# ---
# # Task 4: Class and methods

# %%
class Portfolio:
    def __init__(self, owner):
        self.owner = owner
        self.holdings = {}  # ticker -> {shares, price_per_share}

#a) 
    def add_asset(self, ticker, shares, price_per_share):
        if ticker in self.holdings:
            self.holdings[ticker]["shares"] += shares
            self.holdings[ticker]["price_per_share"] = price_per_share
        else: self.holdings[ticker] = {"shares": shares, "price_per_share": price_per_share}

#b) 
    def total_value(self):
        total = 0
        for share in self.holdings.values():
           total += (share["shares"])*(share["price_per_share"])
        return total

#c) 
    def most_valuable(self):
        return max(self.holdings, key=lambda ticker: self.holdings[ticker]["shares"] * self.holdings[ticker]["price_per_share"])

#d)
    def __str__(self):
        return f"Portfolio owner: {self.owner}, Number of assets: {len(self.holdings)}, Total value: {self.total_value()}"

portfolio = Portfolio("Wincent")
portfolio.add_asset("HEL: NOKIA", 200, 1.50)
portfolio.add_asset("INTC", 5, 47.20)
portfolio.add_asset("MSFT", 1, 350)
print(f"The total value of the portfolio is {portfolio.total_value()}.")
print(f"The most valuable holding value of the portfolio is{portfolio.most_valuable()}.")
print(portfolio.__str__())
# Out:
# The total value of the portfolio is 886.0.
# The most valuable holding value of the portfolio isMSFT.
# Portfolio owner: Wincent, Number of assets: 3, Total value: 886.0

# %% [markdown]
# ---
# # Task 5: Importing a module

# %%
#https://docs.python.org/3/library/datetime.html#date-objects

from datetime import datetime as dt

orders = [
    ("2025-01-15", "Laptop"), ("2025-01-22", "Phone"),
    ("2025-02-03", "Laptop"), ("2025-02-14", "Tablet"),
    ("2025-03-01", "Phone"), ("2025-03-10", "Phone"),
    ("2025-03-22", "Laptop"), ("2025-04-05", "Monitor"),
]

dates = []
for order in orders:
    dates.append(dt.strptime(order[0], "%Y-%m-%d").date())

earliest = min(dates)
latest = max(dates)
difference = latest-earliest


print(f"difference: {difference}")
# Out:
# difference: 80 days, 0:00:00

# %% [markdown]
# ---
# # Task 6: Array Operations and Broadcasting

# %%
import numpy as np
import pandas as pd
# Rows: years (2022, 2023, 2024), Columns: quarters (Q1, Q2, Q3, Q4)
revenue = np.array([
    [210, 230, 190, 250],
    [220, 260, 200, 270],
    [250, 290, 230, 310]])

#https://www.askpython.com/python-modules/pandas/axis-parameter-pandas
#a)
print("a)")
df = pd.DataFrame(revenue)
print(df.sum(axis=1))

#b)
print("b)")
print(df.mean(axis=0))
#c)
print("c)")
growth = np.array([1.05, 1.03, 1.08, 1.02])
print(revenue[2]*growth)

#d)
print("d)")
boolean_mask = revenue > 250
print(revenue[boolean_mask])
# Out:
# a)
# 0     880
# 1     950
# 2    1080
# dtype: int64
# b)
# 0    226.666667
# 1    260.000000
# 2    206.666667
# 3    276.666667
# dtype: float64
# c)
# [262.5 298.7 248.4 316.2]
# d)
# [260 270 290 310]

# %% [markdown]
# ---
# # Task 7: Pandas

# %%
import pandas as pd
data = {
    "employee": ["Anna", "Erik", "Mia", "Leo", "Sara", "Tom"],
    "department": ["Finance", "Marketing", "Finance", "IT", "Marketing", "IT"],
    "salary": [4500, 4000, 4800, 5200, 3900, 5100],
    "years_exp": [5, 3, 7, 10, 2, 8],
    "performance_score": [4.2, 3.8, 4.5, 4.0, 3.5, 4.9]
}

df=pd.DataFrame(data)


#a)
df['salary_per_year_exp'] = round(df['salary']/df['years_exp']).astype(int)

#b)
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
print("b)")

sorted = df.sort_values(by="performance_score", ascending=False)
#https://github.com/m3xw3ll/LeetCode/blob/master/Pandas/185_department_top_three_salaries.md
print(sorted.head(3))

#c)
print("c)")
#https://jakevdp.github.io/PythonDataScienceHandbook/03.02-data-indexing-and-selection.html
abovefour = df.loc[(df["department"] == "Finance") & (df["performance_score"] > 4.0)]
print(abovefour)

#d)
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html
df = df.rename(columns={"years_exp": "experience_years"})

#e)
print("e)")

print(df.iloc[0:4, [2, 4]])
# Out:
# b)
#   employee department  salary  years_exp  performance_score  \
# 5      Tom         IT    5100          8                4.9
# 2      Mia    Finance    4800          7                4.5
# 0     Anna    Finance    4500          5                4.2
#
#    salary_per_year_exp
# 5                  638
# 2                  686
# 0                  900
# c)
#   employee department  salary  years_exp  performance_score  \
# 0     Anna    Finance    4500          5                4.2
# 2      Mia    Finance    4800          7                4.5
#
#    salary_per_year_exp
# 0                  900
# 2                  686
# e)
#    salary  performance_score
# 0    4500                4.2
# 1    4000                3.8
# 2    4800                4.5
# 3    5200                4.0

# %% [markdown]
# ---
# # Task 8: More Pandas

# %%
import numpy as np
import pandas as pd

rng = np.random.default_rng(seed=123)
days = pd.date_range(start="2025-01-06", periods=28, freq="D")
visitors = rng.integers(200, 600, size=28)
conversion_rate = rng.uniform(0.02, 0.08, size=28).round(4)
avg_order_value = rng.normal(50, 10, size=28).round(2)

#a)
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_dict.html#pandas.DataFrame.from_dict
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html
data= {'date': days, 'visitors': visitors, 'conversion_rate': conversion_rate, 'avg_order_value': avg_order_value}
df = pd.DataFrame.from_dict(data, orient='columns').set_index('date')

#b)
df['conversions'] = df['visitors']*df['conversion_rate']
df['daily_revenue'] = df['conversions']*df['avg_order_value']
df
# Out:
#             visitors  conversion_rate  avg_order_value  conversions  \
# date
# 2025-01-06       206           0.0645            64.30      13.2870
# 2025-01-07       472           0.0578            48.44      27.2816
# 2025-01-08       437           0.0756            43.26      33.0372
# 2025-01-09       221           0.0339            43.61       7.4919
# 2025-01-10       563           0.0679            49.39      38.2277
# 2025-01-11       288           0.0511            46.07      14.7168
# 2025-01-12       302           0.0339            72.90      10.2378
# 2025-01-13       273           0.0300            42.82       8.1900
# 2025-01-14       333           0.0499            50.33      16.6167
# 2025-01-15       270           0.0550            50.28      14.8500
# 2025-01-16       339           0.0311            50.28      10.5429
# 2025-01-17       524           0.0209            50.55      10.9516
# 2025-01-18       380           0.0483            45.18      18.3540
# ...
